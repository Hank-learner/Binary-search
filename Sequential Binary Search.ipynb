# %% [markdown]
# # Sequential Binary Search
#
# n sorted integer elements in an array list,
# searching for a position of value x in the list

# %% [markdown]
# Function to search the list
# Input:
# starting index: l
# ending index: r
# search value: x
# (integers)
# Output:
# index || -1 (integer)

# %%
import time
import random

# %%
def binarySearch (arr, l, r, x): 
    if r >= l: 
        mid = l + (r - l) // 2
        if arr[mid] == x: 
            return mid 
        elif arr[mid] > x: 
            return binarySearch(arr, l, mid-1, x) 
        else: 
            return binarySearch(arr, mid + 1, r, x) 
    else:
        return -1

# %% [markdown]
# input array and search value x

# %%
sortedArray=[]
n=100000

sortedArray.append(1)
for i in range(1, n): 
    ele = random.randint(sortedArray[i-1],sortedArray[i-1] + 10)
    sortedArray.append(ele)
    
x=sortedArray[random.randint(1,n-1)]

print(sortedArray)
# Out:
# [1, 8, 10, 11, 19, 25, 25, 33, 39, 47, 52, 60, 62, 64, 72, 79, 85, 92, 96, 98, 108, 110, 113, 120, 129, 134, 138, 148, 149, 151, 160, 162, 162, 168, 177, 177, 186, 193, 202, 206, 212, 216, 217, 224, 232, 234, 242, 242, 251, 258, 258, 267, 272, 282, 289, 291, 291, 295, 296, 298, 304, 311, 311, 314, 315, 322, 325, 325, 333, 342, 343, 343, 345, 347, 357, 363, 373, 383, 392, 401, 410, 417, 422, 427, 430, 438, 440, 441, 443, 449, 459, 462, 469, 470, 479, 487, 497, 502, 511, 517, 517, 522, 529, 531, 541, 541, 543, 551, 561, 562, 566, 572, 580, 589, 594, 604, 607, 610, 612, 620, 629, 638, 638, 643, 651, 652, 652, 652, 658, 661, 663, 671, 680, 682, 692, 693, 696, 696, 703, 711, 719, 720, 730, 731, 736, 740, 749, 752, 758, 765, 768, 775, 785, 795, 799, 804, 805, 814, 820, 825, 833, 837, 844, 844, 846, 852, 856, 860, 869, 877, 880, 883, 888, 897, 903, 907, 912, 912, 921, 926, 928, 928, 935, 942, 946, 955, 957, 959, 963, 971, 973, 979, 987, 996, 999, 1006, 1007, 1009, 1016, 1024, 1033, 1042, 10
# ...

# %% [markdown]
# executing sample data

# %%
start = time.time()
result = binarySearch(sortedArray, 0, n-1, x) 
end = time.time()

if result != -1: 
    print ("Element %d is present at index % d" % (x,result)) 
else: 
    print ("Element %d is not present in array"  % (x))
    
print(f"Runtime of the program is {end - start}")
# Out:
# Element 436022 is present at index  87130
# Runtime of the program is 6.0558319091796875e-05

# %% [markdown]
# element is identified and time for execution is calculated
